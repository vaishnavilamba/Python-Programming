# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.sqrt(3)
# Out:
# 1.7320508075688772

# %%
from math import sqrt,pi
print(sqrt(25))
print(sqrt(9))
print(pi)
# Out:
# 5.0
# 3.0
# 3.141592653589793

# %%
import numpy as np

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
## import all the inbuilt functions 
from math import *
print(cbrt(8))
print(sqrt(4))
print(pi)
# Out:
# 2.0
# 2.0
# 3.141592653589793

# %%
from package.math import addition
addition(2,3)
# Out:
# 5

# %%
from package import math
math.addition(2,3)
# Out:
# 5

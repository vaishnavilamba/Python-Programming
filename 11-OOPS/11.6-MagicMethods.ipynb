# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

person = Person("Vaishnavi",21)
print(person)
# Out:
# <__main__.Person object at 0x000001AD9B29CAD0>

# %%
dir(person)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'name']

# %%
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"The person name is {self.name} and she is {self.age} year old." 
    
    def __repr__(self):
        return f"Name : {self.name} and Age : {self.age}"

person = Person("Vaishnavi",21)
print(person)        
print(repr(person))
# Out:
# The person name is Vaishnavi and she is 21 year old.
# Name : Vaishnavi and Age : 21

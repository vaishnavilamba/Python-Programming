# %%
import logging

# %%
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

# %%
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# %%
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt='%y:%m:%d %H:%M:%S '
)

# %%
logger1.debug("This is debug message for module 1")
logger2.warning("This is a warning message for module 2")
logger2.error("This is error message for module2")
# Out:
# 26:09:14 09:52:50 -module1-DEBUG-This is debug message for module 1
# 26:09:14 09:52:50 -module2-WARNING-This is a warning message for module 2
# 26:09:14 09:52:50 -module2-ERROR-This is error message for module2

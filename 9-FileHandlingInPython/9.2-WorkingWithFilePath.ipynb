# %%
## Create new Directory
import os
new_directory = 'package'
os.mkdir(new_directory)
print(f"New directory '{new_directory}' created")
# Out:
# New directory 'package' created

# %%
## List files and directories
items = os.listdir('.')
print(items)
# Out:
# ['9.1-FileOperation.ipynb', '9.2-WorkingWithFilePath.ipynb', 'destination.txt', 'example.bin', 'example.txt', 'FUnctionsInFileHandling.txt', 'package']

# %%
## Joining Paths

dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\vaish\OneDrive\Desktop\Udempy_Course_AI\Python\9-FileHandlingInPython\folder\file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"The path '{path}' exists")
else:
    print(f"The path '{path}' doesn't exists")
# Out:
# The path 'example.txt' exists

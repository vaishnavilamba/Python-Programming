# %%
import pandas as pd

# %%
df = pd.read_csv('Practice_Data.csv')

# %%
df.head()
# Out:
#   Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0    STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1    STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2    STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3    STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4    STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
#
#    Attendance_%  Study_Hours_Daily  ...  Midterm_Marks  Final_Exam_Marks  \
# 0          71.9                1.0  ...             49                90
# 1          74.4                5.1  ...             83                88
# 2          55.6                1.2  ...             94                43
# 3          74.1                6.1  ...             88                33
# 4          69.6                2.4  ...             87                53
#
#    Project_Marks  Coding_Score  Communication_Score  Sleep_Hours  \
# ...

# %%
df.tail()
# Out:
#     Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 248    STU1249   Mohit   21  Female  Ahmedabad          IT         5    Yes
# 249    STU1250  Simran   23    Male    Kolkata         ECE         1     No
# 250    STU1011   Aryan   23  Female    Chennai  Mechanical         7    Yes
# 251    STU1051   Aarav   23  Female    Kolkata         ECE         5    Yes
# 252    STU1101   Aarav   21  Female       Pune       Civil         7    Yes
#
#      Attendance_%  Study_Hours_Daily  ...  Midterm_Marks  Final_Exam_Marks  \
# 248          59.2                2.7  ...             42                83
# 249          71.2                3.2  ...             88                59
# 250          67.5                3.6  ...             35                48
# 251          82.5                4.8  ...             98                67
# 252          81.7                2.6  ...             51                57
#
# ...

# %%
df.describe()
# Out:
#               Age    Semester  Attendance_%  Study_Hours_Daily  Assignment_%  \
# count  253.000000  253.000000    253.000000         248.000000    248.000000
# mean    20.545455    4.553360     77.746640           4.383871     71.472177
# std      1.730592    2.380918     12.417977           2.083398     16.045017
# min     18.000000    1.000000     55.200000           1.000000     45.200000
# 25%     19.000000    2.000000     68.300000           2.600000     57.750000
# 50%     21.000000    5.000000     78.200000           4.650000     70.950000
# 75%     22.000000    7.000000     87.800000           6.100000     83.825000
# max     23.000000    8.000000     99.900000           8.000000     99.900000
#
#        Midterm_Marks  Final_Exam_Marks  Project_Marks  Coding_Score  \
# count     253.000000        253.000000     253.000000    253.000000
# mean       67.086957         63.822134      71.027668     60.778656
# std        18.982248         19.103415      17.278623     23.528234
# ...

# %%
df.dtypes
# Out:
# Student_ID                 str
# Name                       str
# Age                      int64
# Gender                     str
# City                       str
# Department                 str
# Semester                 int64
# Hostel                     str
# Attendance_%           float64
# Study_Hours_Daily      float64
# Assignment_%           float64
# Midterm_Marks            int64
# Final_Exam_Marks         int64
# Project_Marks            int64
# Coding_Score             int64
# Communication_Score    float64
# Sleep_Hours            float64
# Screen_Time_Hours      float64
# Annual_Fees              int64
# Grade                      str
# Attendance_Status          str
# dtype: object

# %%
df.isnull().any()
# Out:
# Student_ID             False
# Name                   False
# Age                    False
# Gender                 False
# City                    True
# Department             False
# Semester               False
# Hostel                 False
# Attendance_%           False
# Study_Hours_Daily       True
# Assignment_%            True
# Midterm_Marks          False
# Final_Exam_Marks       False
# Project_Marks          False
# Coding_Score           False
# Communication_Score     True
# Sleep_Hours            False
# Screen_Time_Hours      False
# Annual_Fees            False
# Grade                  False
# Attendance_Status      False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Student_ID             0
# Name                   0
# Age                    0
# Gender                 0
# City                   5
# Department             0
# Semester               0
# Hostel                 0
# Attendance_%           0
# Study_Hours_Daily      5
# Assignment_%           5
# Midterm_Marks          0
# Final_Exam_Marks       0
# Project_Marks          0
# Coding_Score           0
# Communication_Score    5
# Sleep_Hours            0
# Screen_Time_Hours      0
# Annual_Fees            0
# Grade                  0
# Attendance_Status      0
# dtype: int64

# %%
df['Study_Hours_fillna'] = df['Study_Hours_Daily'].fillna(df['Study_Hours_Daily'].mean())

# %%
df
# Out:
#     Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0      STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1      STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2      STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3      STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4      STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
# ..         ...     ...  ...     ...        ...         ...       ...    ...
# 248    STU1249   Mohit   21  Female  Ahmedabad          IT         5    Yes
# 249    STU1250  Simran   23    Male    Kolkata         ECE         1     No
# 250    STU1011   Aryan   23  Female    Chennai  Mechanical         7    Yes
# 251    STU1051   Aarav   23  Female    Kolkata         ECE         5    Yes
# 252    STU1101   Aarav   21  Female       Pune       Civil         7    Yes
#
# ...

# %%
df = df.rename(columns={'Study_Hours_fillna':'New_Value_StudyHours'})

# %%
df
# Out:
#     Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0      STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1      STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2      STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3      STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4      STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
# ..         ...     ...  ...     ...        ...         ...       ...    ...
# 248    STU1249   Mohit   21  Female  Ahmedabad          IT         5    Yes
# 249    STU1250  Simran   23    Male    Kolkata         ECE         1     No
# 250    STU1011   Aryan   23  Female    Chennai  Mechanical         7    Yes
# 251    STU1051   Aarav   23  Female    Kolkata         ECE         5    Yes
# 252    STU1101   Aarav   21  Female       Pune       Civil         7    Yes
#
# ...

# %%
df['New_value'] = df['Attendance_%'].fillna(df['Attendance_%'].mean()).astype(int)

# %%
df.head()
# Out:
#   Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0    STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1    STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2    STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3    STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4    STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
#
#    Attendance_%  Study_Hours_Daily  ...  Coding_Score  Communication_Score  \
# 0          71.9                1.0  ...            94                 53.0
# 1          74.4                5.1  ...            79                 44.0
# 2          55.6                1.2  ...            28                  NaN
# 3          74.1                6.1  ...            82                 47.0
# 4          69.6                2.4  ...            79                 70.0
#
# ...

# %%
df['Value_New'] = df['New_Value'].apply(lambda x:x*2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\Udempy_Course_AI\Python\venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
df.drop('Value_New',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df.drop('Value_New',axis=1,inplace=True)
#
# File ~\OneDrive\Desktop\Udempy_Course_AI\Python\venv\Lib\site-packages\pandas\core\frame.py:6302, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6298                 weight  250.0   150.0
#    6299         falcon  speed   320.0   250.0
#    6300                 weight  1.0     0.8
#    6301         """
# -> 6302         return super().drop(
#    6303             labels=labels,
#    6304             axis=axis,
#    6305             index=index,
#
# File ~\OneDrive\Desktop\Udempy_Course_AI\Python\venv\Lib\site-packages\pandas\core\generic.py:4632, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4628         obj = self
#    4629
#    4630         for axis, labels in axes.items():
# ...

# %%
df.head()
# Out:
#   Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0    STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1    STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2    STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3    STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4    STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
#
#    Attendance_%  Study_Hours_Daily  ...  Project_Marks  Coding_Score  \
# 0          71.9                1.0  ...             60            94
# 1          74.4                5.1  ...             81            79
# 2          55.6                1.2  ...             89            28
# 3          74.1                6.1  ...             93            82
# 4          69.6                2.4  ...             65            79
#
#    Communication_Score  Sleep_Hours  Screen_Time_Hours  Annual_Fees  Grade  \
# ...

# %%
df['Value_New'] = df['New_value'].apply(lambda x:x*2)

# %%
df.head()
# Out:
#   Student_ID    Name  Age  Gender       City  Department  Semester Hostel  \
# 0    STU1001  Aditya   23    Male      Delhi  Mechanical         6     No
# 1    STU1002   Varun   23    Male     Mumbai  Mechanical         7     No
# 2    STU1003  Vivaan   21  Female    Chennai  Mechanical         5     No
# 3    STU1004   Aryan   21  Female  Ahmedabad     AI & DS         4     No
# 4    STU1005   Harsh   22    Male   Haridwar         CSE         8    Yes
#
#    Attendance_%  Study_Hours_Daily  ...  Coding_Score  Communication_Score  \
# 0          71.9                1.0  ...            94                 53.0
# 1          74.4                5.1  ...            79                 44.0
# 2          55.6                1.2  ...            28                  NaN
# 3          74.1                6.1  ...            82                 47.0
# 4          69.6                2.4  ...            79                 70.0
#
# ...

# %%
df.dtypes
# Out:
# Student_ID                  str
# Name                        str
# Age                       int64
# Gender                      str
# City                        str
# Department                  str
# Semester                  int64
# Hostel                      str
# Attendance_%            float64
# Study_Hours_Daily       float64
# Assignment_%            float64
# Midterm_Marks             int64
# Final_Exam_Marks          int64
# Project_Marks             int64
# Coding_Score              int64
# Communication_Score     float64
# Sleep_Hours             float64
# Screen_Time_Hours       float64
# Annual_Fees               int64
# Grade                       str
# Attendance_Status           str
# New_Value_StudyHours    float64
# New_value                 int64
# Value_New                 int64
# dtype: object

# %%
grouped_mean = df.groupby('Gender')['Midterm_Marks'].mean()
print(grouped_mean)
# Out:
# Gender
# Female    67.582609
# Male      66.673913
# Name: Midterm_Marks, dtype: float64

# %%
grouped_mean = df.groupby('City')['Project_Marks'].mean()
print(grouped_mean)
# Out:
# City
# Ahmedabad    70.206897
# Bangalore    72.518519
# Chennai      75.421053
# Delhi        62.956522
# Haridwar     79.730769
# Hyderabad    65.880000
# Jaipur       75.434783
# Kolkata      71.640000
# Mumbai       66.055556
# Pune         71.606061
# Name: Project_Marks, dtype: float64

# %%
grouped_mean = df.groupby(['City','Gender'])['Project_Marks'].mean()
print(grouped_mean)
# Out:
# City       Gender
# Ahmedabad  Female    75.785714
#            Male      65.000000
# Bangalore  Female    76.769231
#            Male      68.571429
# Chennai    Female    74.769231
#            Male      76.833333
# Delhi      Female    70.777778
#            Male      57.928571
# Haridwar   Female    80.083333
#            Male      79.428571
# Hyderabad  Female    64.875000
#            Male      67.666667
# Jaipur     Female    70.000000
#            Male      78.333333
# Kolkata    Female    75.000000
#            Male      70.058824
# Mumbai     Female    67.600000
#            Male      65.461538
# Pune       Female    69.375000
#            Male      73.705882
# Name: Project_Marks, dtype: float64

# %%
grouped_mean = df.groupby('City')[['Project_Marks','Midterm_Marks']].mean()
print(grouped_mean)
# Out:
#            Project_Marks  Midterm_Marks
# City
# Ahmedabad      70.206897      69.551724
# Bangalore      72.518519      71.333333
# Chennai        75.421053      64.368421
# Delhi          62.956522      58.565217
# Haridwar       79.730769      69.384615
# Hyderabad      65.880000      67.400000
# Jaipur         75.434783      65.043478
# Kolkata        71.640000      71.440000
# Mumbai         66.055556      64.666667
# Pune           71.606061      66.272727

# %%
grouped = df.groupby(['City','Gender'])['Project_Marks'].agg(['mean','count','sum'])
print(grouped)
# Out:
#                        mean  count   sum
# City      Gender
# Ahmedabad Female  75.785714     14  1061
#           Male    65.000000     15   975
# Bangalore Female  76.769231     13   998
#           Male    68.571429     14   960
# Chennai   Female  74.769231     13   972
#           Male    76.833333      6   461
# Delhi     Female  70.777778      9   637
#           Male    57.928571     14   811
# Haridwar  Female  80.083333     12   961
#           Male    79.428571     14  1112
# Hyderabad Female  64.875000     16  1038
#           Male    67.666667      9   609
# Jaipur    Female  70.000000      8   560
#           Male    78.333333     15  1175
# Kolkata   Female  75.000000      8   600
#           Male    70.058824     17  1191
# Mumbai    Female  67.600000      5   338
#           Male    65.461538     13   851
# Pune      Female  69.375000     16  1110
#           Male    73.705882     17  1253

# %%
## Merging and Joining Data Frames
df1 = pd.DataFrame({'key':['A','B','C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'key':['A','B','D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
pd.merge(df1,df2,on='key',how='inner')
# Out:
#   key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on='key',how='outer')
# Out:
#   key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on='key',how='left')
# Out:
#   key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on='key',how='right')
# Out:
#   key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6

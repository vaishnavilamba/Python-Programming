# %%
import pandas as pd
from io import StringIO

# %%
Data = '{"employee_name":"James","email":"james@gmail.com","job_profile":[{"title1":"Team Lead","title2":"Sr. Developer"}]}'

# %%
df = pd.read_json(StringIO(Data))

# %%
df
# Out:
#   employee_name            email  \
# 0         James  james@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Lead', 'title2': 'Sr. Develop...

# %%
df.to_json()
# Out:
# '{"employee_name":{"0":"James"},"email":{"0":"james@gmail.com"},"job_profile":{"0":{"title1":"Team Lead","title2":"Sr. Developer"}}}'

# %%
df.to_json(orient='index')
# Out:
# '{"0":{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}}'

# %%
df.to_json(orient='records')
# Out:
# '[{"employee_name":"James","email":"james@gmail.com","job_profile":{"title1":"Team Lead","title2":"Sr. Developer"}}]'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris-data.csv?utm_source=chatgpt.com')

# %%
df.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.to_csv('https://raw.githubusercontent.com/plotly/datasets/master/iris-data.csv?utm_source=chatgpt.com')

# %%
url = 'https://html.spec.whatwg.org/multipage/?utm_source=chatgpt.com'

# %%
# !pip install lxml
# !pip install html5lib
# !pip install beautifulsoup4
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ------- -------------------------------- 0.8/4.0 MB 2.8 MB/s eta 0:00:02
#    ------------- -------------------------- 1.3/4.0 MB 2.8 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/4.0 MB 3.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 2.9/4.0 MB 3.4 MB/s eta 0:00:01
#    ------------------------------------ --- 3.7/4.0 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------- 4.0/4.0 MB 3.3 MB/s  0:00:01
# ...
# [notice] A new release of pip is available: 25.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
#    -------------------- ------------------- 1/2 [html5lib]
# ...

# %%
url = 'https://www.w3schools.com/html/html_table_sizes.asp'

# %%
url = "https://gist.githubusercontent.com/hasankadirdemircan/889c14cb5f650dad49af45dedf977a1d/raw/table.html"

# %%
df = pd.read_html(url)

# %%
df
# Out:
# [                        Company           Contact  Country
#  0           Alfreds Futterkiste      Maria Anders  Germany
#  1    Centro comercial Moctezuma   Francisco Chang   Mexico
#  2                  Ernst Handel     Roland Mendel  Austria
#  3                Island Trading     Helen Bennett       UK
#  4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
#  5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy]

# %%
df[0]
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy

# %%
# !pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
pd.read_excel('short_student_data.xlsx')
# Out:
#     Name  Age Course  Marks
# 0   Aman   20    CSE     85
# 1  Priya   21    CSE     92
# 2  Rahul   20    ECE     78
# 3   Neha   21     IT     88
# 4   Riya   20    CSE     95

# %%
df_excel = pd.read_excel('short_student_data.xlsx')

# %%
df.to_pickle('df_excel')

# %%
pd.read_pickle('df_excel')
# Out:
#     Name  Age Course  Marks
# 0   Aman   20    CSE     85
# 1  Priya   21    CSE     92
# 2  Rahul   20    ECE     78
# 3   Neha   21     IT     88
# 4   Riya   20    CSE     95
